# %% [markdown]
#  # Library Imports

# %%
# Import necessary libraries for data analysis and visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive

# Configure visualization settings
sns.set_context("notebook", font_scale=1.5)

# Mount Google Drive to access files
# Skip remounting if already mounted
try:
    from google.colab import drive
    drive.mount('/content/drive')
except:
    print("Drive already mounted or not in Colab environment.")

file_path = '/content/drive/My Drive/Fintech/businessCase2/Dataset4_EWS.xlsx'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# pip install tensorflow numpy scikit-learn matplotlib

# %% [markdown]
# # Data Loading
#
# From Bloomberg, consisting of weekly observations of:
#
# - Market and macroeconomic indicators (e.g., indices, rates).
# - A response variable `Y` indicating **anomalous periods** (e.g., market stress events).

# %%
# Set visualization style
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = [10, 6]

# Load the data from the Excel file
# First sheet contains market data with dates and anomaly labels, second sheet contains metadata
data_df = pd.read_excel(file_path, sheet_name='Markets')
metadata_df = pd.read_excel(file_path, sheet_name='Metadata')

# Check the structure of the loaded data
print("Data columns:", data_df.columns.tolist())

# Extract date and anomaly label columns
date_col = 'Date' if 'Date' in data_df.columns else data_df.columns[0]
y_col = 'Y' if 'Y' in data_df.columns else None

# Convert dates to datetime format
data_df[date_col] = pd.to_datetime(data_df[date_col], dayfirst=True)  # Date format is dd/mm/yy

# Set date as index
data_df = data_df.set_index(date_col)

# Extract features (all columns except Y if it exists)
if y_col:
    X_df = data_df.drop(y_col, axis=1)
    y = data_df[y_col].values
else:
    X_df = data_df
    y = None

# Display basic information about the dataset
print(f"Data shape: {X_df.shape}")
print(f"Total number of records: {len(X_df)}")
print(f"Time period: from {X_df.index.min().strftime('%m/%d/%Y')} to {X_df.index.max().strftime('%m/%d/%Y')}")
print(f"Frequency: {pd.infer_freq(X_df.index) or 'Weekly'}")
print(f"Number of variables: {X_df.shape[1]}")
if y_col:
    print(f"Number of anomalies: {np.sum(y == 1)} ({np.mean(y == 1)*100:.2f}%)")

# Create a more comprehensive metadata table with additional statistics
enhanced_metadata = []

# Determine the correct column names for ticker and description
ticker_col = 'ticker' if 'ticker' in metadata_df.columns else metadata_df.columns[0]
desc_col = 'description' if 'description' in metadata_df.columns else metadata_df.columns[1] if len(metadata_df.columns) > 1 else ticker_col

for ticker in X_df.columns:
    # Get metadata for this ticker if available
    meta_row = metadata_df[metadata_df[ticker_col] == ticker] if ticker in metadata_df[ticker_col].values else pd.DataFrame()

    # Get description or use ticker if not found
    description = meta_row[desc_col].values[0] if not meta_row.empty and desc_col in meta_row.columns else ticker

    # Calculate statistics for this series
    series = X_df[ticker]

    enhanced_metadata.append({
        'Ticker': ticker,
        'Description': description,
        'Mean': series.mean(),
        'Std.Dev': series.std(),
        'Min': series.min(),
        'Max': series.max(),
        'Missing values': series.isna().sum(),
        'Missing (%)': f"{series.isna().mean()*100:.2f}%"
    })

# Create enhanced metadata dataframe
enhanced_meta_df = pd.DataFrame(enhanced_metadata)

# Display the enhanced metadata
print("\nMetadata and statistics:")
display(enhanced_meta_df)
# Out:
# Data columns: ['Data', 'BDIY', 'CRY', 'Cl1', 'DXY', 'ECSURPUS', 'EMUSTRUU', 'EONIA', 'GBP', 'GT10', 'GTDEM10Y', 'GTDEM2Y', 'GTDEM30Y', 'GTGBP20Y', 'GTGBP2Y', 'GTGBP30Y', 'GTITL10YR', 'GTITL2YR', 'GTITL30YR', 'GTJPY10YR', 'GTJPY2YR', 'GTJPY30YR', 'JPY', 'LF94TRUU', 'LF98TRUU', 'LG30TRUU', 'LMBITR', 'LP01TREU', 'LUACTRUU', 'LUMSTRUU', 'MXBR', 'MXCN', 'MXEU', 'MXIN', 'MXJP', 'MXRU', 'MXUS', 'US0001M', 'USGG2YR', 'USGG30YR', 'USGG3M', 'VIX', 'XAUBGNL', 'Y']
# Data shape: (1111, 42)
# Total number of records: 1111
# Time period: from 01/11/2000 to 04/20/2021
# Frequency: W-TUE
# Number of variables: 42
# Number of anomalies: 237 (21.33%)
#
# Metadata and statistics:
#        Ticker                     Description         Mean      Std.Dev  \
# 0        BDIY                Baltic Dry Index  2259.860486  2017.811888
# 1         CRY              TR/CC CRB ER Index   245.247649    68.278081
# 2         Cl1         Generic 1st 'CL' Future    60.708101    25.900813
# 3         DXY               DOLLAR INDEX SPOT    90.934982    11.379095
# 4    ECSURPUS  Bloomberg ECO US Surprise Inde     0.036153     0.349453
# 5    EMUSTRUU                EM USD Aggregate   704.379495   309.951768
# 6       EONIA  EMMI EURO OverNight Index Aver     1.363676     1.721894
# 7         GBP              British Pound Spot     1.569618     0.212340
# 8        GT10                 US TREASURY N/B     3.266748     1.332464
# 9    GTDEM10Y        BUNDESREPUB. DEUTSCHLAND     2.448365     1.851558
# 10    GTDEM2Y         BUNDESSCHATZANWEISUNGEN     1.431110     1.876061
# 11   GTDEM30Y        BUNDESREPUB. DEUTSCHLAND     3.039282     1.779526
# 12   GTGBP20Y              UK TSY 1 1/4% 2041     3.445731     1.366188
# 13    GTGBP2Y              UK TSY 0 1/8% 2023     2.299739     2.128539
# 14   GTGBP30Y              UK TSY 0 5/8% 2050     3.450121     1.263211
# 15  GTITL10YR        BUONI POLIENNALI DEL TES     3.680791     1.465289
# 16   GTITL2YR        BUONI POLIENNALI DEL TES     2.104911     1.700726
# 17  GTITL30YR        BUONI POLIENNALI DEL TES     4.426725     1.274729
# 18  GTJPY10YR           JAPAN (10 YEAR ISSUE)     0.904126     0.643985
# 19   GTJPY2YR            JAPAN (2 YEAR ISSUE)     0.150180     0.297519
# 20  GTJPY30YR           JAPAN (30 YEAR ISSUE)     1.724494     0.720026
# 21        JPY               Japanese Yen Spot   106.605734    12.840754
# 22   LF94TRUU         Global Inflation-Linked   259.052663    75.934443
# 23   LF98TRUU         US Corporate High Yield  1231.258119   553.121000
# 24   LG30TRUU               Global High Yield   804.720625   370.251996
# 25     LMBITR            Municipal Bond Index   883.615439   241.507125
# 26   LP01TREU         Pan-European High Yield   232.109928   109.917622
# 27   LUACTRUU                       Corporate  2077.306949   690.731794
# 28   LUMSTRUU                        U.S. MBS  1637.293510   417.229338
# 29       MXBR                     MSCI BRAZIL  1903.216436   986.468254
# 30       MXCN                      MSCI CHINA    53.933159    24.738356
# 31       MXEU                     MSCI EUROPE   107.877138    20.795973
# 32       MXIN                      MSCI INDIA   693.156616   405.527014
# 33       MXJP                      MSCI JAPAN   784.846292   200.076443
# 34       MXRU                     MSCI RUSSIA   648.681377   299.096020
# 35       MXUS                        MSCI USA  1606.997102   698.481956
# 36    US0001M           ICE LIBOR USD 1 Month     1.836073     1.909032
# 37    USGG2YR            US Generic Govt 2 Yr     1.990358     1.710307
# 38   USGG30YR           US Generic Govt 30 Yr     3.908324     1.178592
# 39     USGG3M           US Generic Govt 3 Mth     1.575151     1.802895
# 40        VIX           Cboe Volatility Index    19.992169     8.642157
# 41    XAUBGNL                         XAUBGNL   987.463744   494.623740
#
#           Min          Max  Missing values Missing (%)
# 0   291.00000  11793.00000               0       0.00%
# 1   106.29290    467.57000               0       0.00%
# 2    10.01000    140.97000               0       0.00%
# 3    71.32900    119.82000               0       0.00%
# 4    -0.97400      0.99100               0       0.00%
# 5   230.52670   1286.35300               0       0.00%
# 6    -0.49800      5.73000               0       0.00%
# 7     1.17230      2.08520               0       0.00%
# 8     0.50800      6.74800               0       0.00%
# 9    -0.79400      5.64400               0       0.00%
# 10   -0.96800      5.26400               0       0.00%
# 11   -0.47100      6.25400               0       0.00%
# 12    0.48920      5.24180               0       0.00%
# 13   -0.16330      6.61250               0       0.00%
# 14    0.54740      5.07480               0       0.00%
# 15    0.51200      7.20900               0       0.00%
# 16   -0.45800      7.01500               0       0.00%
# 17    1.38600      7.50000               0       0.00%
# 18   -0.29100      1.96800               0       0.00%
# 19   -0.35100      1.08000               0       0.00%
# 20    0.05600      3.12800               0       0.00%
# 21   75.94000    134.63000               0       0.00%
# 22  121.33100    398.70650               0       0.00%
# 23  491.08000   2378.53000               0       0.00%
# 24  294.36740   1525.79000               0       0.00%
# 25  472.72330   1350.50000               0       0.00%
# 26   80.79680    431.55280               0       0.00%
# 27  986.94000   3550.43000               0       0.00%
# 28  869.33000   2325.86000               0       0.00%
# 29  280.50000   4721.36000               0       0.00%
# 30   13.46000    129.20000               0       0.00%
# 31   56.30000    146.39000               0       0.00%
# 32  112.60000   1730.51000               0       0.00%
# 33  431.71000   1210.58000               0       0.00%
# 34  151.25000   1617.64000               0       0.00%
# 35  663.69000   4043.69000               0       0.00%
# 36    0.10575      6.77625               0       0.00%
# 37    0.10730      6.87200               0       0.00%
# 38    1.16260      6.74700               0       0.00%
# 39   -0.03810      6.41400               0       0.00%
# 40    9.43000     75.91000               0       0.00%
# 41  256.68000   2006.91000               0       0.00%

# %% [markdown]
# # Autoencoder
# ### What is an autoencoder?
# An autoencoder is a type of neural network architecture that learns to compress data into a lower-dimensional representation (encoding) and then reconstruct the original data from this compressed form (decoding).
#
# ### How an autoencoder is used for binary classification
# An autoencoder is trained only on normal data to learn how to reconstruct it accurately. At test time, it reconstructs new inputs. If the reconstruction error is low, the data is likely normal; if high, it’s considered an anomaly. A threshold on the error is used to classify samples as normal or anomalous. This makes autoencoders effective for unsupervised anomaly detection.
#
# ### Why use an autoencoder?
# The main benefits of using autoencoders for binary classification include:
#
# *   Ability to work well with limited labeled data
# *   Effective dimensionality reduction
# *   Potential for better handling of imbalanced datasets
# *   Anomaly detection capabilities

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from sklearn.utils import shuffle
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score
import seaborn as sns

# %% [markdown]
# # Autoencoder for binary classification

# %% [markdown]
# ### Data Preparation
# Splits data into training, validation, and test sets through shuffle:
#
#
# *   **Training set:** contains only normal data (class 0) -> 80% of the normal data
# *   **Validation set:** contains both normal and anomaly data (classes 0 and 1) -> 10% of the normal data and 50% of the anomalies
# *   **Test set:** contains both normal and anomaly data (classes 0 and 1) -> 10% of the normal data and 50% of the anomalies

# %%
# --- Dataset ---
X = X_df.values

# --- Split data into Training, Validation and Test sets ---
# Shuffle
X_shuffled, y_shuffled = shuffle(X, y, random_state=42)

X_normal = X_shuffled[y_shuffled == 0]
X_anomaly = X_shuffled[y_shuffled == 1]

n_normal = X_normal.shape[0]
n_anomaly = X_anomaly.shape[0]

train_size = int(0.8 * n_normal)
cv_normal_size = int(0.1 * n_normal)
cv_anomaly_size = int(0.5 * n_anomaly)

X_train_raw = X_normal[:train_size]
X_cv_normal = X_normal[train_size:train_size + cv_normal_size]
X_cv_anomaly = X_anomaly[:cv_anomaly_size]
X_cross_val_raw = np.vstack((X_cv_normal, X_cv_anomaly))
y_cross_val = np.hstack((np.zeros(cv_normal_size), np.ones(cv_anomaly_size)))

X_test_normal = X_normal[train_size + cv_normal_size:]
X_test_anomaly = X_anomaly[cv_anomaly_size:]
X_test_raw = np.vstack((X_test_normal, X_test_anomaly))
y_test = np.hstack((np.zeros(len(X_test_normal)), np.ones(len(X_test_anomaly))))

# --- StandardScaler ---
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train_raw)
X_cross_val = scaler.transform(X_cross_val_raw)
X_test = scaler.transform(X_test_raw)

print(f"Training set size: {X_train.shape[0]} (all normal)")
print(f"Cross-validation set size: {X_cross_val.shape[0]} ({cv_normal_size} normal, {cv_anomaly_size} anomalies)")
print(f"Test set size: {X_test.shape[0]} ({len(X_test_normal)} normal, {len(X_test_anomaly)} anomalies)")
# Out:
# Training set size: 699 (all normal)
# Cross-validation set size: 205 (87 normal, 118 anomalies)
# Test set size: 207 (88 normal, 119 anomalies)

# %% [markdown]
# ### Autoencoder Architecture
# *   **Input layer:** Matches the input data dimension
# *   **Encoder:** Two hidden layers (128 → 64 neurons) with ReLU activation
# *   **Bottleneck:** Latent space with 20 dimensions
# *   **Decoder:** Two hidden layers (64 → 128 neurons) with ReLU activation
# *   **Output layer:** Reconstructs the original input dimension
#
# Uses batch normalization and L2 regularization for stability

# %%
# --- Hyperparameters ---
LATENT_DIM = 30
INPUT_DIM = X_train.shape[1]
REG_STRENGTH = 1e-5           # L2 regularization strength

# --- Autoencoder class ---
def build_autoencoder():

    # Input Layer
    encoder_inputs = layers.Input(shape=(INPUT_DIM,))

    # Encoder
    x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(REG_STRENGTH))(encoder_inputs)
    x = layers.BatchNormalization()(x)

    x = layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(REG_STRENGTH))(x)
    x = layers.BatchNormalization()(x)

    # Bottleneck -> Latent space
    latent = layers.Dense(LATENT_DIM, activation='relu', name='latent_layer')(x)

    # Decoder
    x = layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(REG_STRENGTH))(latent)
    x = layers.BatchNormalization()(x)

    x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(REG_STRENGTH))(x)
    x = layers.BatchNormalization()(x)

    # Output Layer
    decoder_outputs = layers.Dense(INPUT_DIM, activation='linear')(x)

    autoencoder = models.Model(encoder_inputs, decoder_outputs, name='autoencoder')
    encoder = models.Model(encoder_inputs, latent, name='encoder')

    return autoencoder, encoder

# %% [markdown]
# ### Training process
# Trains only on normal data (training set):
#
#
# **Objective:** Minimize the reconstruction error using Mean Squared Error (MSE) loss between the original input X and the reconstructed output X. The autoencoder learns to reproduce input data as accurately as possible.
# Since the model trains exclusively on normal data, it becomes highly effective at reconstructing normal patterns while performing poorly on anomalous patterns. This asymmetry enables anomaly detection:
# *  *Low reconstruction error* → Normal data (follows learned patterns).
# *  *High reconstruction error* → Anomalous data (deviates from learned patterns).
#
#
# Uses **Adam optimizer** with learning rate 0.001.
#
# Implements **early stopping** and **learning rate reduction**.
#
# Monitors **validation loss** to prevent overfitting.

# %%
autoencoder, encoder = build_autoencoder()

# --- Compile and show the summary of the model ---
autoencoder.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='mse'
)
autoencoder.summary()

# --- Early Stopping ---
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=20,
    verbose=1,
    restore_best_weights=True
)

# --- Learning Rate reduction ---
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=0.00001,
    verbose=1
)

# --- Training Autoencoder  ---
history = autoencoder.fit(
    X_train, X_train,     # The objective is the reconstruction: original X = reconstructed X
    epochs=200,
    batch_size=64,
    validation_split=0.1, # Internal Validation
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)

# --- Plot Autoencoder Training and Validation Loss ---
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Autoencoder Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Model: "autoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_9 (InputLayer)      │ (None, 42)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_45 (Dense)                │ (None, 128)            │         5,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_36          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_46 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_37          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ latent_layer (Dense)            │ (None, 30)             │         1,950 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_47 (Dense)                │ (None, 64)             │         1,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_38          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_48 (Dense)                │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_39          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_49 (Dense)                │ (None, 42)             │         5,418 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 32,968 (128.78 KB)
#  Trainable params: 32,200 (125.78 KB)
#  Non-trainable params: 768 (3.00 KB)
# Epoch 1/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 2.0345 - val_loss: 1.0150 - learning_rate: 0.0010
# Epoch 2/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7717 - val_loss: 0.9129 - learning_rate: 0.0010
# Epoch 3/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3956 - val_loss: 0.8386 - learning_rate: 0.0010
# Epoch 4/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2284 - val_loss: 0.7889 - learning_rate: 0.0010
# Epoch 5/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1566 - val_loss: 0.7267 - learning_rate: 0.0010
# Epoch 6/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1409 - val_loss: 0.6739 - learning_rate: 0.0010
# Epoch 7/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1493 - val_loss: 0.6277 - learning_rate: 0.0010
# Epoch 8/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1077 - val_loss: 0.5770 - learning_rate: 0.0010
# Epoch 9/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1034 - val_loss: 0.5321 - learning_rate: 0.0010
# Epoch 10/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1062 - val_loss: 0.4907 - learning_rate: 0.0010
# Epoch 11/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0866 - val_loss: 0.4432 - learning_rate: 0.0010
# Epoch 12/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0781 - val_loss: 0.4120 - learning_rate: 0.0010
# Epoch 13/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0792 - val_loss: 0.3707 - learning_rate: 0.0010
# Epoch 14/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0761 - val_loss: 0.3396 - learning_rate: 0.0010
# Epoch 15/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0800 - val_loss: 0.3021 - learning_rate: 0.0010
# Epoch 16/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0722 - val_loss: 0.2709 - learning_rate: 0.0010
# Epoch 17/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0694 - val_loss: 0.2388 - learning_rate: 0.0010
# Epoch 18/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0648 - val_loss: 0.2116 - learning_rate: 0.0010
# Epoch 19/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0675 - val_loss: 0.1897 - learning_rate: 0.0010
# Epoch 20/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0829 - val_loss: 0.1693 - learning_rate: 0.0010
# Epoch 21/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0640 - val_loss: 0.1495 - learning_rate: 0.0010
# Epoch 22/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0659 - val_loss: 0.1333 - learning_rate: 0.0010
# Epoch 23/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0664 - val_loss: 0.1155 - learning_rate: 0.0010
# Epoch 24/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0599 - val_loss: 0.1039 - learning_rate: 0.0010
# Epoch 25/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0534 - val_loss: 0.0926 - learning_rate: 0.0010
# Epoch 26/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0513 - val_loss: 0.0829 - learning_rate: 0.0010
# Epoch 27/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0595 - val_loss: 0.0753 - learning_rate: 0.0010
# Epoch 28/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0649 - val_loss: 0.0668 - learning_rate: 0.0010
# Epoch 29/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0619 - val_loss: 0.0598 - learning_rate: 0.0010
# Epoch 30/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0464 - val_loss: 0.0552 - learning_rate: 0.0010
# Epoch 31/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0625 - val_loss: 0.0496 - learning_rate: 0.0010
# Epoch 32/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0537 - val_loss: 0.0468 - learning_rate: 0.0010
# Epoch 33/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0554 - val_loss: 0.0436 - learning_rate: 0.0010
# Epoch 34/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0566 - val_loss: 0.0399 - learning_rate: 0.0010
# Epoch 35/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0472 - val_loss: 0.0384 - learning_rate: 0.0010
# Epoch 36/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0554 - val_loss: 0.0361 - learning_rate: 0.0010
# Epoch 37/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0538 - val_loss: 0.0367 - learning_rate: 0.0010
# Epoch 38/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0489 - val_loss: 0.0340 - learning_rate: 0.0010
# Epoch 39/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0468 - val_loss: 0.0327 - learning_rate: 0.0010
# Epoch 40/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0565 - val_loss: 0.0305 - learning_rate: 0.0010
# Epoch 41/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0522 - val_loss: 0.0304 - learning_rate: 0.0010
# Epoch 42/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0608 - val_loss: 0.0308 - learning_rate: 0.0010
# Epoch 43/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0478 - val_loss: 0.0287 - learning_rate: 0.0010
# Epoch 44/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0419 - val_loss: 0.0274 - learning_rate: 0.0010
# Epoch 45/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0404 - val_loss: 0.0272 - learning_rate: 0.0010
# Epoch 46/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0481 - val_loss: 0.0265 - learning_rate: 0.0010
# Epoch 47/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0378 - val_loss: 0.0264 - learning_rate: 0.0010
# Epoch 48/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0475 - val_loss: 0.0253 - learning_rate: 0.0010
# Epoch 49/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0419 - val_loss: 0.0247 - learning_rate: 0.0010
# Epoch 50/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0388 - val_loss: 0.0255 - learning_rate: 0.0010
# Epoch 51/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0468 - val_loss: 0.0256 - learning_rate: 0.0010
# Epoch 52/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0379 - val_loss: 0.0243 - learning_rate: 0.0010
# Epoch 53/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0447 - val_loss: 0.0253 - learning_rate: 0.0010
# Epoch 54/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0364 - val_loss: 0.0251 - learning_rate: 0.0010
# Epoch 55/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0619 - val_loss: 0.0258 - learning_rate: 0.0010
# Epoch 56/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0479 - val_loss: 0.0237 - learning_rate: 0.0010
# Epoch 57/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0380 - val_loss: 0.0234 - learning_rate: 0.0010
# Epoch 58/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0426 - val_loss: 0.0241 - learning_rate: 0.0010
# Epoch 59/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0458 - val_loss: 0.0237 - learning_rate: 0.0010
# Epoch 60/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0402 - val_loss: 0.0224 - learning_rate: 0.0010
# Epoch 61/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0387 - val_loss: 0.0219 - learning_rate: 0.0010
# Epoch 62/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0424 - val_loss: 0.0232 - learning_rate: 0.0010
# Epoch 63/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0441 - val_loss: 0.0227 - learning_rate: 0.0010
# Epoch 64/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0446 - val_loss: 0.0233 - learning_rate: 0.0010
# Epoch 65/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0435 - val_loss: 0.0227 - learning_rate: 0.0010
# Epoch 66/200
#  1/10 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0283
# Epoch 66: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0391 - val_loss: 0.0241 - learning_rate: 0.0010
# Epoch 67/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0392 - val_loss: 0.0218 - learning_rate: 5.0000e-04
# Epoch 68/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0442 - val_loss: 0.0204 - learning_rate: 5.0000e-04
# Epoch 69/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0432 - val_loss: 0.0212 - learning_rate: 5.0000e-04
# Epoch 70/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0385 - val_loss: 0.0198 - learning_rate: 5.0000e-04
# Epoch 71/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0361 - val_loss: 0.0199 - learning_rate: 5.0000e-04
# Epoch 72/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0446 - val_loss: 0.0208 - learning_rate: 5.0000e-04
# Epoch 73/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0530 - val_loss: 0.0195 - learning_rate: 5.0000e-04
# Epoch 74/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0342 - val_loss: 0.0192 - learning_rate: 5.0000e-04
# Epoch 75/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0381 - val_loss: 0.0196 - learning_rate: 5.0000e-04
# Epoch 76/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0512 - val_loss: 0.0198 - learning_rate: 5.0000e-04
# Epoch 77/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0492 - val_loss: 0.0192 - learning_rate: 5.0000e-04
# Epoch 78/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0462 - val_loss: 0.0190 - learning_rate: 5.0000e-04
# Epoch 79/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0400 - val_loss: 0.0187 - learning_rate: 5.0000e-04
# Epoch 80/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0362 - val_loss: 0.0187 - learning_rate: 5.0000e-04
# Epoch 81/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0524 - val_loss: 0.0187 - learning_rate: 5.0000e-04
# Epoch 82/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0434 - val_loss: 0.0188 - learning_rate: 5.0000e-04
# Epoch 83/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0415 - val_loss: 0.0182 - learning_rate: 5.0000e-04
# Epoch 84/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0327 - val_loss: 0.0182 - learning_rate: 5.0000e-04
# Epoch 85/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0401 - val_loss: 0.0184 - learning_rate: 5.0000e-04
# Epoch 86/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0384 - val_loss: 0.0179 - learning_rate: 5.0000e-04
# Epoch 87/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0474 - val_loss: 0.0181 - learning_rate: 5.0000e-04
# Epoch 88/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0356 - val_loss: 0.0178 - learning_rate: 5.0000e-04
# Epoch 89/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0408 - val_loss: 0.0176 - learning_rate: 5.0000e-04
# Epoch 90/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0439 - val_loss: 0.0173 - learning_rate: 5.0000e-04
# Epoch 91/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0370 - val_loss: 0.0176 - learning_rate: 5.0000e-04
# Epoch 92/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0364 - val_loss: 0.0176 - learning_rate: 5.0000e-04
# Epoch 93/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0414 - val_loss: 0.0174 - learning_rate: 5.0000e-04
# Epoch 94/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0421 - val_loss: 0.0184 - learning_rate: 5.0000e-04
# Epoch 95/200
#  9/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0315
# Epoch 95: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0317 - val_loss: 0.0173 - learning_rate: 5.0000e-04
# Epoch 96/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0445 - val_loss: 0.0170 - learning_rate: 2.5000e-04
# Epoch 97/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0234 - val_loss: 0.0170 - learning_rate: 2.5000e-04
# Epoch 98/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0323 - val_loss: 0.0167 - learning_rate: 2.5000e-04
# Epoch 99/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0439 - val_loss: 0.0167 - learning_rate: 2.5000e-04
# Epoch 100/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0414 - val_loss: 0.0165 - learning_rate: 2.5000e-04
# Epoch 101/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0406 - val_loss: 0.0165 - learning_rate: 2.5000e-04
# Epoch 102/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0349 - val_loss: 0.0168 - learning_rate: 2.5000e-04
# Epoch 103/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0347 - val_loss: 0.0164 - learning_rate: 2.5000e-04
# Epoch 104/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0402 - val_loss: 0.0165 - learning_rate: 2.5000e-04
# Epoch 105/200
#  1/10 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - loss: 0.0228
# Epoch 105: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0337 - val_loss: 0.0165 - learning_rate: 2.5000e-04
# Epoch 106/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0318 - val_loss: 0.0163 - learning_rate: 1.2500e-04
# Epoch 107/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0485 - val_loss: 0.0163 - learning_rate: 1.2500e-04
# Epoch 108/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0402 - val_loss: 0.0161 - learning_rate: 1.2500e-04
# Epoch 109/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0392 - val_loss: 0.0162 - learning_rate: 1.2500e-04
# Epoch 110/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0330 - val_loss: 0.0160 - learning_rate: 1.2500e-04
# Epoch 111/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0374 - val_loss: 0.0159 - learning_rate: 1.2500e-04
# Epoch 112/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0378 - val_loss: 0.0159 - learning_rate: 1.2500e-04
# Epoch 113/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0329 - val_loss: 0.0160 - learning_rate: 1.2500e-04
# Epoch 114/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0417 - val_loss: 0.0160 - learning_rate: 1.2500e-04
# Epoch 115/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0327 - val_loss: 0.0158 - learning_rate: 1.2500e-04
# Epoch 116/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0330 - val_loss: 0.0159 - learning_rate: 1.2500e-04
# Epoch 117/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0410 - val_loss: 0.0159 - learning_rate: 1.2500e-04
# Epoch 118/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0322 - val_loss: 0.0161 - learning_rate: 1.2500e-04
# Epoch 119/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0313 - val_loss: 0.0158 - learning_rate: 1.2500e-04
# Epoch 120/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0559
# Epoch 120: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0550 - val_loss: 0.0159 - learning_rate: 1.2500e-04
# Epoch 121/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0319 - val_loss: 0.0159 - learning_rate: 6.2500e-05
# Epoch 122/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0290 - val_loss: 0.0158 - learning_rate: 6.2500e-05
# Epoch 123/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0330 - val_loss: 0.0158 - learning_rate: 6.2500e-05
# Epoch 124/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0320 - val_loss: 0.0158 - learning_rate: 6.2500e-05
# Epoch 125/200
#  1/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0240
# Epoch 125: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0293 - val_loss: 0.0158 - learning_rate: 6.2500e-05
# Epoch 126/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0332 - val_loss: 0.0158 - learning_rate: 3.1250e-05
# Epoch 127/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0332 - val_loss: 0.0158 - learning_rate: 3.1250e-05
# Epoch 128/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0424 - val_loss: 0.0158 - learning_rate: 3.1250e-05
# Epoch 129/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0486 - val_loss: 0.0158 - learning_rate: 3.1250e-05
# Epoch 130/200
#  1/10 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - loss: 0.0181
# Epoch 130: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0287 - val_loss: 0.0158 - learning_rate: 3.1250e-05
# Epoch 131/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0330 - val_loss: 0.0158 - learning_rate: 1.5625e-05
# Epoch 132/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0382 - val_loss: 0.0158 - learning_rate: 1.5625e-05
# Epoch 133/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0301 - val_loss: 0.0158 - learning_rate: 1.5625e-05
# Epoch 134/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0306 - val_loss: 0.0158 - learning_rate: 1.5625e-05
# Epoch 135/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0384
# Epoch 135: ReduceLROnPlateau reducing learning rate to 1e-05.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0388 - val_loss: 0.0158 - learning_rate: 1.5625e-05
# Epoch 136/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0326 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 137/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0383 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 138/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0297 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 139/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0331 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 140/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0527 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 141/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0288 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 142/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0380 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 143/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0453 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 144/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0341 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 145/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0312 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 146/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0320 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 147/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0297 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 148/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0461 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 149/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0417 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 150/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0386 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 151/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0319 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 152/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0301 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 153/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0356 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 154/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0387 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 155/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0278 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 156/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0439 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 157/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0351 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 158/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0299 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 159/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0372 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 160/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0326 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 161/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0318 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 162/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0280 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 163/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0299 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 164/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0312 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 165/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0492 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 166/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0301 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 167/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0387 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 168/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0317 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 169/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0335 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 170/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0335 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 171/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0283 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 172/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0413 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 173/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0382 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 174/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0319 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 175/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0360 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 176/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0436 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 177/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0311 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 178/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0328 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 179/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0323 - val_loss: 0.0158 - learning_rate: 1.0000e-05
# Epoch 180/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0325 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 181/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0363 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 182/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0258 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 183/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0309 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 184/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0382 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 185/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0309 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 186/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0350 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 187/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0321 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 188/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0320 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 189/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0358 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 190/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0502 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 191/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0235 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 192/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0287 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 193/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0356 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 194/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0293 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 195/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0360 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 196/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0351 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 197/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0425 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 198/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0384 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 199/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0278 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Epoch 200/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0330 - val_loss: 0.0157 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 196.

# %% [markdown]
# ### Anomaly Detection Process
#
# 1. **Compute Reconstruction Error:**
# For each sample, the autoencoder attempts to reconstruct the input. The reconstruction error is calculated as the Mean Squared Error between the original input and the reconstructed output.
# Higher reconstruction error indicates likely anomaly because the autoencoder was trained only on normal data and struggles to reconstruct patterns it hasn't seen before.
# 2. **Threshold Optimization on Validation Set**:
# Calculate reconstruction errors for all samples in the validation set (which contains both normal and anomaly data).
# Test different threshold values across the range of reconstruction errors.
# For each threshold, classify samples as:
#      *   **anomaly** if error > threshold.
#      *   **normal** if error ≤ threshold.
#
#   Evaluate classification performance using F1-score.
#
# 3. **Final Classification on Test Set:**
# Apply the optimized threshold to the test set reconstruction errors
# Evaluate final model performance using the test set results

# %%
# --- Compute reconstruction error ---
def compute_anomaly_score(x):
    # Reconstruction
    x_reconstructed = autoencoder.predict(np.array([x]), verbose=0)[0]

    # Mean Squared Error
    reconstruction_error = np.mean(np.square(x - x_reconstructed))

    return reconstruction_error

# --- Compute reconstruction error on validation set and test set  ---
print("Calculating reconstruction error on the validation set...")
scores_cv = np.array([compute_anomaly_score(x) for x in X_cross_val])

print("Calculating reconstruction error on the test set...")
scores_test = np.array([compute_anomaly_score(x) for x in X_test])

# --- Display the distribution of reconstruction error scores on the validation set ---
plt.figure(figsize=(10, 6))
plt.hist(scores_cv[y_cross_val == 0], bins=30, alpha=0.7, label='Normal', density=True)
plt.hist(scores_cv[y_cross_val == 1], bins=30, alpha=0.7, label='Anomaly', density=True)
plt.title('Distribution of Reconstruction Errors on Validation Set')
plt.xlabel('Reconstruction Error')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()

# --- Compute ROC AUC ---
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_cross_val, scores_cv)
roc_auc = auc(fpr, tpr)
print(f"ROC AUC on validation set: {roc_auc:.4f}")

# ROC curve
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.3f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# --- Threshold Optimization on Validation Set: ---
print("\nThreshold Optimization...")
print("Thresh\tPrecision\tRecall\tF1\tAccuracy")

best_f1 = 0
best_thresh = 0
best_metrics = None
thresholds = np.linspace(0,0.1, 100)
f1_scores=[]
for thresh in np.linspace(0,0.1, 100):

    y_pred_cv = (scores_cv > thresh).astype(int)
    prec = precision_score(y_cross_val, y_pred_cv)
    rec = recall_score(y_cross_val, y_pred_cv)
    f1_cv = f1_score(y_cross_val, y_pred_cv)
    acc = accuracy_score(y_cross_val, y_pred_cv)

    f1_adjusted = f1_cv
    f1_scores.append(f1_adjusted)
    if f1_adjusted > best_f1:
        best_f1 = f1_adjusted
        best_thresh = thresh
        best_metrics = (prec, rec, f1_cv, acc)

    if thresh % (np.percentile(scores_cv, 99) - np.percentile(scores_cv, 1)) / 20 < (np.percentile(scores_cv, 99) - np.percentile(scores_cv, 1)) / 100:
        print(f"{thresh:.4f}\t{prec:.3f}\t\t{rec:.3f}\t{f1_cv:.3f}\t{acc:.3f}")


prec, rec, f1_cv, acc = best_metrics
print(f"\nBest Threshold: {best_thresh:.4f}")
print(f"Precision: {prec:.3f}, Recall: {rec:.3f}, F1: {f1_cv:.3f}, Accuracy: {acc:.3f}")

plt.plot(thresholds, f1_scores)
plt.axvline(x=best_thresh, color='r', linestyle='--', label=f'Optimal = {best_thresh:.4f}')
plt.xlabel('Threshold')
plt.ylabel('F1 Score')
plt.title('F1 Score vs Threshold')
plt.legend()
plt.grid(True, alpha=0.3)
# Out:
# Calculating reconstruction error on the validation set...
# Calculating reconstruction error on the test set...
# ROC AUC on validation set: 0.8656
# Threshold Optimization...
# Thresh	Precision	Recall	F1	Accuracy
# 0.0000	0.576		1.000	0.731	0.576
# 0.0010	0.576		1.000	0.731	0.576
# 0.0020	0.576		1.000	0.731	0.576
# 0.0030	0.581		1.000	0.735	0.585
# 0.0040	0.581		1.000	0.735	0.585
# 0.0051	0.605		1.000	0.754	0.624
# 0.0061	0.616		0.992	0.760	0.639
# 0.0071	0.628		0.975	0.764	0.654
# 0.0081	0.663		0.966	0.786	0.698
# 0.0091	0.694		0.941	0.799	0.727
# 0.0101	0.703		0.924	0.799	0.732
# 0.0111	0.719		0.890	0.795	0.737
# 0.0121	0.750		0.864	0.803	0.756
# 0.0131	0.782		0.822	0.802	0.766
# 0.0141	0.807		0.780	0.793	0.766
# 0.0152	0.850		0.771	0.809	0.790
# 0.0162	0.843		0.729	0.782	0.766
# 0.0172	0.848		0.712	0.774	0.761
# 0.0182	0.891		0.695	0.781	0.776
# 0.0192	0.908		0.669	0.771	0.771
# 0.0202	0.918		0.661	0.768	0.771
# 0.0212	0.927		0.644	0.760	0.766
# 0.0222	0.927		0.644	0.760	0.766
# 0.0232	0.937		0.627	0.751	0.761
# 0.0242	0.944		0.576	0.716	0.737
# 0.0253	0.944		0.576	0.716	0.737
# 0.0263	0.955		0.542	0.692	0.722
# 0.0273	0.952		0.508	0.663	0.702
# 0.0283	0.952		0.500	0.656	0.698
# 0.0293	0.950		0.483	0.640	0.688
# 0.0303	0.948		0.466	0.625	0.678
# 0.0313	0.944		0.432	0.593	0.659
# 0.0323	0.944		0.432	0.593	0.659
# 0.0333	0.944		0.432	0.593	0.659
# 0.0343	0.962		0.432	0.596	0.663
# 0.0354	0.980		0.415	0.583	0.659
# 0.0364	0.980		0.407	0.575	0.654
# 0.0374	0.979		0.390	0.558	0.644
# 0.0384	0.978		0.381	0.549	0.639
# 0.0394	0.978		0.381	0.549	0.639
# 0.0404	0.978		0.373	0.540	0.634
# 0.0414	0.978		0.373	0.540	0.634
# 0.0424	1.000		0.364	0.534	0.634
# 0.0434	1.000		0.364	0.534	0.634
# 0.0444	1.000		0.364	0.534	0.634
# 0.0455	1.000		0.364	0.534	0.634
# 0.0465	1.000		0.356	0.525	0.629
# 0.0475	1.000		0.347	0.516	0.624
# 0.0485	1.000		0.347	0.516	0.624
# 0.0495	1.000		0.339	0.506	0.620
# 0.0505	1.000		0.339	0.506	0.620
# 0.0515	1.000		0.339	0.506	0.620
# 0.0525	1.000		0.322	0.487	0.610
# 0.0535	1.000		0.322	0.487	0.610
# 0.0545	1.000		0.322	0.487	0.610
# 0.0556	1.000		0.314	0.477	0.605
# 0.0566	1.000		0.314	0.477	0.605
# 0.0576	1.000		0.305	0.468	0.600
# 0.0586	1.000		0.305	0.468	0.600
# 0.0596	1.000		0.305	0.468	0.600
# 0.0606	1.000		0.305	0.468	0.600
# 0.0616	1.000		0.288	0.447	0.590
# 0.0626	1.000		0.288	0.447	0.590
# 0.0636	1.000		0.280	0.437	0.585
# 0.0646	1.000		0.280	0.437	0.585
# 0.0657	1.000		0.271	0.427	0.580
# 0.0667	1.000		0.271	0.427	0.580
# 0.0677	1.000		0.263	0.416	0.576
# 0.0687	1.000		0.263	0.416	0.576
# 0.0697	1.000		0.263	0.416	0.576
# 0.0707	1.000		0.263	0.416	0.576
# 0.0717	1.000		0.246	0.395	0.566
# 0.0727	1.000		0.246	0.395	0.566
# 0.0737	1.000		0.246	0.395	0.566
# 0.0747	1.000		0.246	0.395	0.566
# 0.0758	1.000		0.246	0.395	0.566
# 0.0768	1.000		0.246	0.395	0.566
# 0.0778	1.000		0.237	0.384	0.561
# 0.0788	1.000		0.237	0.384	0.561
# 0.0798	1.000		0.229	0.372	0.556
# 0.0808	1.000		0.229	0.372	0.556
# 0.0818	1.000		0.229	0.372	0.556
# 0.0828	1.000		0.229	0.372	0.556
# 0.0838	1.000		0.220	0.361	0.551
# 0.0848	1.000		0.220	0.361	0.551
# 0.0859	1.000		0.220	0.361	0.551
# 0.0869	1.000		0.220	0.361	0.551
# 0.0879	1.000		0.220	0.361	0.551
# 0.0889	1.000		0.220	0.361	0.551
# 0.0899	1.000		0.220	0.361	0.551
# 0.0909	1.000		0.220	0.361	0.551
# 0.0919	1.000		0.220	0.361	0.551
# 0.0929	1.000		0.220	0.361	0.551
# 0.0939	1.000		0.220	0.361	0.551
# 0.0949	1.000		0.220	0.361	0.551
# 0.0960	1.000		0.220	0.361	0.551
# 0.0970	1.000		0.220	0.361	0.551
# 0.0980	1.000		0.220	0.361	0.551
# 0.0990	1.000		0.212	0.350	0.546
# 0.1000	1.000		0.212	0.350	0.546
#
# Best Threshold: 0.0152
# Precision: 0.850, Recall: 0.771, F1: 0.809, Accuracy: 0.790

# %% [markdown]
# ### Evaluation & Visualization
# Compute and displays the model's performance on the test set:
#
# *   Confusion Matrix
# *   Accuracy
# *   Precision
# *   Recall
# *   F1 Score
#
# #### Calculate and Visualize feature importance:
#
# 1. A random sample is taken from the test set.
#
# 2. The sample is reconstructed using the autoencoder.
#
# 3. The mean absolute reconstruction error is computed for each feature.
#
# 4. The errors are normalized to give relative importance scores.

# %%
# --- Evaluate performance on the test set ---
y_pred_test = (scores_test > best_thresh).astype(int)

cm = confusion_matrix(y_test, y_pred_test)
precision = precision_score(y_test, y_pred_test)
recall = recall_score(y_test, y_pred_test)
f1 = f1_score(y_test, y_pred_test)
accuracy = accuracy_score(y_test, y_pred_test)

print("\n--- Metriche di valutazione finali sul Test Set ---")
print(f"Confusion Matrix:\n{cm}")
print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")

# --- Display the distribution of reconstruction error scores on the test set ---
plt.figure(figsize=(10, 6))
plt.hist(scores_test[y_test == 0], bins=30, alpha=0.7, label='Normal', density=True)
plt.hist(scores_test[y_test == 1], bins=30, alpha=0.7, label='Anomaly', density=True)
plt.axvline(best_thresh, color='r', linestyle='--', label=f'Threshold {best_thresh:.4f}')
plt.title('Distribution of Reconstruction Errors on Test Set')
plt.xlabel('Reconstruction Error')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()

# --- Confusion matrix ---
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Normal', 'Anomaly'],
            yticklabels=['Normal', 'Anomaly'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# --- Feature importance based on autoencoder ---
# Computes feature importance based on the reconstruction error per feature
def feature_importance():
    # Take a sample from the test set
    sample_size = min(500, X_test.shape[0])
    sample_indices = np.random.choice(X_test.shape[0], sample_size, replace=False)
    X_sample = X_test[sample_indices]

    # Reconstruct
    X_reconstructed = autoencoder.predict(X_sample)

    # Compute the error per feature
    feature_errors = np.mean(np.abs(X_sample - X_reconstructed), axis=0)

    # Normalize
    feature_importance = feature_errors / np.sum(feature_errors)

    return feature_importance

# Compute and visualize feature importance
feature_imp = feature_importance()

plt.figure(figsize=(12, 6))
plt.bar(range(len(feature_imp)), feature_imp)
plt.title('Feature Importance Based on Reconstruction Error')
plt.xlabel('Feature Index')
plt.ylabel('Importance')
plt.grid(True, axis='y')
plt.show()

# Show the top 10 most important features
top_indices = np.argsort(feature_imp)[-10:]
print("\nTop 10 feature più importanti (indice, importanza):")
for idx in reversed(top_indices):
    print(f"Feature {idx}: {feature_imp[idx]:.4f}")
# Out:
# --- Metriche di valutazione finali sul Test Set ---
# Confusion Matrix:
# [[ 67  21]
#  [ 17 102]]
# Accuracy:  0.8164
# Precision: 0.8293
# Recall:    0.8571
# F1 Score:  0.8430
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Top 10 feature più importanti (indice, importanza):
# Feature 40: 0.0814
# Feature 4: 0.0399
# Feature 16: 0.0363
# Feature 38: 0.0347
# Feature 0: 0.0335
# Feature 34: 0.0296
# Feature 8: 0.0296
# Feature 33: 0.0295
# Feature 7: 0.0295
# Feature 31: 0.0294
